# %%
# %pip freeze | grep sagemaker
# Out:
# sagemaker==2.235.2
# sagemaker-core==1.0.77
# sagemaker-experiments==0.1.45
# sagemaker_training==4.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sagemaker
from sagemaker.estimator import Estimator
from sagemaker import get_execution_role
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
role = get_execution_role()
sess = sagemaker.Session()

# %% [markdown]
# ## Model Train job 실행

# %%
# ============================================
# Estimator 생성
# ============================================
estimator = Estimator(
    # 앞서 빌드한 SageMaker 이미지 사용
    image_uri="155954279556.dkr.ecr.us-east-1.amazonaws.com/gs-automl-base-containers/tabular-kunops-311_sm:1.0",
    role=role,
    instance_count=1,
    instance_type="ml.m5.large",  # 또는 ml.m5.xlarge

    # 하이퍼파라미터 → run_pm.py parse_args() → papermill → 노트북 parameters 셀
    # SageMaker는 모든 값을 string으로 전달하므로 str로 통일
    hyperparameters={
        # LightGBM hyperparameters
        "objective": "binary",
        "metric": "binary_logloss",
        "num_leaves": "31",
        "learning_rate": "0.1",
        "n_estimators": "100",
        "max_depth": "10",
        "random_state": "42",
        "verbose": "0",
        # train/val split
        "val_ratio": "0.2",
        "random_state_split": "42",
    },

    base_job_name="train-titanic-lightgbm",
    sagemaker_session=sess,

    # 태그
    tags=[
        {"Key": "Environment", "Value": "dev"},
        {"Key": "Project", "Value": "automl"},
        {"Key": "Owner", "Value": "hjsong"},
        {"Key": "CostCenter", "Value": "gs-retail"},
    ],

    # 출력 경로
    output_path="s3://retail-mlops-edu-2026/edu-2w/kunops/output",
)

# %%
# ============================================
# 학습 데이터 준비
# ============================================
# 학습 데이터를 S3에 업로드
train_s3_path = sess.upload_data(
    path='train.csv',
    bucket='retail-mlops-edu-2026',
    key_prefix='edu-2w/kunops/input'
)

print(f"Training data uploaded to: {train_s3_path}")
# Out:
# Training data uploaded to: s3://retail-mlops-edu-2026/edu-2w/kunops/input/train.csv

# %%
# ============================================
# Training Job 실행
# ============================================
try:
    estimator.fit({
        'training': train_s3_path
    })

    print("=" * 60)
    print("✅ Training Job 완료!")
    print(f"   Job Name: {estimator.latest_training_job.name}")
    print(f"   Model Artifact: {estimator.model_data}")
    print("=" * 60)

except Exception as e:
    print(f"❌ Training Job 실패: {e}")
# Out:
# INFO:sagemaker:Creating training-job with name: train-titanic-lightgbm-2026-02-27-17-12-28-078
# 2026-02-27 17:12:28 Starting - Starting the training job...
# 2026-02-27 17:12:54 Starting - Preparing the instances for training...
# 2026-02-27 17:13:20 Downloading - Downloading input data...
# 2026-02-27 17:13:50 Downloading - Downloading the training image......
# 2026-02-27 17:14:41 Training - Training image download completed. Training in progress.2026-02-27 17:14:44,433 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-02-27 17:14:44,433 sagemaker-training-toolkit INFO     Failed to parse hyperparameter metric value binary_logloss to Json.
# Returning the value itself
# 2026-02-27 17:14:44,434 sagemaker-training-toolkit INFO     Failed to parse hyperparameter objective value binary to Json.
# Returning the value itself
# 2026-02-27 17:14:44,434 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-02-27 17:14:44,450 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-02-27 17:14:44,451 sagemaker-training-toolkit INFO     Failed to parse hyperparameter metric value binary_logloss to Json.
# Returning the value itself
# 2026-02-27 17:14:44,451 sagemaker-training-toolkit INFO     Failed to parse hyperparameter objective value binary to Json.
# Returning the value itself
# 2026-02-27 17:14:44,452 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-02-27 17:14:44,463 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-02-27 17:14:44,464 sagemaker-training-toolkit INFO     Failed to parse hyperparameter metric value binary_logloss to Json.
# Returning the value itself
# 2026-02-27 17:14:44,464 sagemaker-training-toolkit INFO     Failed to parse hyperparameter objective value binary to Json.
# Returning the value itself
# 2026-02-27 17:14:44,465 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-02-27 17:14:44,476 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.m5.large",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": null,
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "learning_rate": 0.1,
#         "max_depth": 10,
#         "metric": "binary_logloss",
#         "n_estimators": 100,
#         "num_leaves": 31,
#         "objective": "binary",
#         "random_state": 42,
#         "random_state_split": 42,
#         "val_ratio": 0.2,
#         "verbose": 0
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.m5.large",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": false,
#     "job_name": "train-titanic-lightgbm-2026-02-27-17-12-28-078",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "run_pm",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.large",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.large",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0",
#         "topology": null
#     },
#     "user_entry_point": "run_pm.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"learning_rate":0.1,"max_depth":10,"metric":"binary_logloss","n_estimators":100,"num_leaves":31,"objective":"binary","random_state":42,"random_state_split":42,"val_ratio":0.2,"verbose":0}
# SM_USER_ENTRY_POINT=run_pm.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0","topology":null}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.m5.large
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=run_pm
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.m5.large","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":null,"hosts":["algo-1"],"hyperparameters":{"learning_rate":0.1,"max_depth":10,"metric":"binary_logloss","n_estimators":100,"num_leaves":31,"objective":"binary","random_state":42,"random_state_split":42,"val_ratio":0.2,"verbose":0},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":false,"job_name":"train-titanic-lightgbm-2026-02-27-17-12-28-078","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"run_pm","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0","topology":null},"user_entry_point":"run_pm.py"}
# SM_USER_ARGS=["--learning_rate","0.1","--max_depth","10","--metric","binary_logloss","--n_estimators","100","--num_leaves","31","--objective","binary","--random_state","42","--random_state_split","42","--val_ratio","0.2","--verbose","0"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_LEARNING_RATE=0.1
# SM_HP_MAX_DEPTH=10
# SM_HP_METRIC=binary_logloss
# SM_HP_N_ESTIMATORS=100
# SM_HP_NUM_LEAVES=31
# SM_HP_OBJECTIVE=binary
# SM_HP_RANDOM_STATE=42
# SM_HP_RANDOM_STATE_SPLIT=42
# SM_HP_VAL_RATIO=0.2
# SM_HP_VERBOSE=0
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python311.zip:/usr/local/lib/python3.11:/usr/local/lib/python3.11/lib-dynload:/usr/local/lib/python3.11/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.11 run_pm.py --learning_rate 0.1 --max_depth 10 --metric binary_logloss --n_estimators 100 --num_leaves 31 --objective binary --random_state 42 --random_state_split 42 --val_ratio 0.2 --verbose 0
# 2026-02-27 17:14:44,477 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2026-02-27 17:14:44,479 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# AWS Account ID: 155954279556
# AWS Region: ap-northeast-2
# === Hyperparameters ===
# {   'dataset_table_name': '',
#     'experiment_hashkey': '',
#     'job_type': 'training',
#     'learning_rate': '0.1',
#     'max_depth': '10',
#     'metric': 'binary_logloss',
#     'n_estimators': '100',
#     'num_leaves': '31',
#     'objective': 'binary',
#     'project_hashkey': '',
#     'random_state': '42',
#     'random_state_split': '42',
#     'table_name': '',
#     'task_token': '',
#     'username': '',
#     'val_ratio': '0.2',
#     'verbose': '0'}
# Passed unknown parameter: job_type
# #015Executing:   0%|          | 0/17 [00:00<?, ?cell/s]#015Executing:   6%|▌         | 1/17 [00:04<01:06,  4.19s/cell]#015Executing:  29%|██▉       | 5/17 [00:05<00:11,  1.03cell/s]#015Executing:  71%|███████   | 12/17 [00:06<00:01,  2.76cell/s]#015Executing:  82%|████████▏ | 14/17 [00:22<00:05,  1.99s/cell]#015Executing:  94%|█████████▍| 16/17 [00:23<00:01,  1.72s/cell]#015Executing: 100%|██████████| 17/17 [00:24<00:00,  1.46s/cell]
# Uploaded to: s3://retail-mlops-edu-2026/edu-2w/kunops/output/train_titanic_lightgbm_output.ipynb
# 2026-02-27 17:15:10,808 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2026-02-27 17:15:29 Uploading - Uploading generated training model
# 2026-02-27 17:15:29 Completed - Training job completed
# Training seconds: 129
# Billable seconds: 129
# ============================================================
# ✅ Training Job 완료!
#    Job Name: train-titanic-lightgbm-2026-02-27-17-12-28-078
#    Model Artifact: s3://retail-mlops-edu-2026/edu-2w/kunops/output/train-titanic-lightgbm-2026-02-27-17-12-28-078/output/model.tar.gz
# ============================================================

# %% [markdown]
# ## 결과 확인

# %%
# ============================================================
# Step 3: 결과 노트북 다운로드 및 확인
# ============================================================

import boto3
import os
import pandas as pd

s3 = boto3.client('s3')

# ============================================
# 실행된 노트북 다운로드
# ============================================
bucket = 'retail-mlops-edu-2026'
key = 'edu-2w/kunops/output/train_titanic_lightgbm_output.ipynb'
local_path = 'titanic_output.ipynb'

s3.download_file(bucket, key, local_path)

print(f"✅ 결과 노트북 다운로드 완료: {local_path}")
print(f"   Jupyter에서 열어서 확인하세요!")

# ============================================
# 모델 다운로드
# ============================================
print(estimator.latest_training_job.name)
model_key = f"edu-2w/hjsong/output/{estimator.latest_training_job.name}/output/model.tar.gz"
model_local = 'model.tar.gz'
s3.download_file(bucket, model_key, model_local)

# 압축 해제
import tarfile
with tarfile.open(model_local, 'r:gz') as tar:
    tar.extractall('model')

print(f"✅ 모델 다운로드 완료: ./model/")

# ============================================
# 모델 로드 및 테스트
# ============================================
import joblib

model = joblib.load('model/titanic_model.joblib')

# 테스트 데이터로 예측
val_key = "edu-2w/hjsong/data/val/validation.csv"
val_local = "test.csv"
s3.download_file(bucket, val_key, val_local)
test_df = pd.read_csv('test.csv')
target_col = "survived" if "survived" in test_df.columns else "target"
X_test = test_df.drop(target_col, axis=1)
y_test = test_df[target_col]
# ... 전처리
predictions = model.predict(X_test)

print(f"✅ 예측 완료: {len(predictions)} samples")
