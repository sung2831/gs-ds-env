# %%
# !aws s3 cp s3://cheonhj-mlops-edu-202602/code/ ./ --recursive
# Out:
# download: s3://cheonhj-mlops-edu-202602/code/staff_titanic.zip to ./staff_titanic.zip

# %%
# !mkdir -p chj && mv staff_titanic.zip chj && cd chj && unzip staff_titanic.zip
# Out:
# Archive:  staff_titanic.zip
#   inflating: notion_submission.md
#  extracting: requirements.txt
#   inflating: Dockerfile
#   inflating: pyproject.toml
#   inflating: progress.md
#   inflating: README.md
#   inflating: .gitignore
#   inflating: train.py
#   inflating: staff_exercise.md
#  extracting: .python-version
#   inflating: AGENTS.md
#   inflating: run_training.py
#   inflating: split_data.py
#    creating: data/
#    creating: data/output/
#   inflating: data/output/val.csv
#   inflating: data/output/train.csv
#   inflating: data/train.csv
#   inflating: CLAUDE.md
